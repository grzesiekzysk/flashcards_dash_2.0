# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import eng_to_ipa

def fix_string(text):
    pattern = r"(\S)\("
    return re.sub(pattern, r"\1 (", text)

class Diki:
    def __init__(self, lang='ENG'):
        self.lang = lang
        self.dict_pop = {
            '*****': 'TOP 1000',
            '****': 'TOP 2000',
            '***': 'TOP 3000',
            '**': 'TOP 4000',
            '*': 'TOP 5000',
        }
        self.data = pd.DataFrame(
            columns=[
                'english_word',
                'pronunciation',
                'part_of_speech',
                'polish_word',
                'eng_example',
                'pol_example',
                'synonyms',
                'opposites'
            ]
        ),
        self.popularity = None
        self.soup = None

    def _bs4_info(self, word):
        langs = {
            'ENG': 'angielskiego',
            'GER': 'niemieckiego',
            'ESP': 'hiszpanskiego',
            'ITA': 'wloskiego',
            'FRA': 'francuskiego'
        }
        
        result = requests.get(f'https://www.diki.pl/slownik-{langs[self.lang]}?q={word}')
        soup = BeautifulSoup(result.text, 'html.parser')
        self.soup = soup

    def extract_data(self, word):
        self._bs4_info(word)
        data_list = []

        try:
            popularity_element = self.soup.find('a', class_='starsForNumOccurrences')
            self.popularity = self.dict_pop[popularity_element.text.strip()] if popularity_element else None
        except AttributeError:
            self.popularity = None

        div_class = self.soup.find_all('div', class_='dictionaryEntity')

        for div in div_class:
            # span_hw = div.find("span", class_="hw")
            # TODO Pomysleć na casem draw/ draw out

            try:
                span_hws = div.find("div", class_="hws").find_all("span", class_="hw")
                english_words = [span.text.strip().lower() for span in span_hws]
            except:
                span_hws = div.find("span", class_="hw")
                english_words = [span_hws.text.strip().lower()]

            if span_hws and word.lower() in english_words:


                for m in div.find_all('li', id=re.compile('^meaning\d+')):

                    # polish_words = [span.get_text(strip=True) for span in m.find_all('span', class_='hw')]
                    polish_words = [span.get_text() for span in m.find_all('span', class_='hw')]
                    polish_word = ', '.join(polish_words)

                    ol_parent = m.find_parent('ol')
                    if ol_parent:
                        part_of_speech_element = ol_parent.find_previous_sibling('div', class_='partOfSpeechSectionHeader')
                        part_of_speech = part_of_speech_element.get_text(strip=True) if part_of_speech_element else None
                        
                        if part_of_speech_element:
                            next_div = part_of_speech_element.find_next_sibling('div')
                            if next_div and ('af' in next_div.get('class', []) or 'vf' in next_div.get('class', [])):
                                other_forms = [span.get_text(strip=True) for span in next_div.find_all('span', class_='foreignTermText')]
                            else:
                                other_forms = []

                    else:
                        part_of_speech = None

                    example_div = m.find('div', class_='exampleSentence')
                    if example_div:
                        example_text = ' '.join(example_div.stripped_strings)
                        eng_example, pol_example = [w.rstrip(')') for w in example_text.split(' (')]
                    else:
                        eng_example, pol_example = None, None

                    synonyms = set()
                    opposites = set()

                    refs = m.find_all('div', class_='ref')
                    for ref in refs:
                        for child_div in ref.find_all('div', recursive=False):
                            text_content = child_div.get_text(strip=True)
                            if text_content.startswith('synon'):
                                links = child_div.find_all('a')
                                synonyms.update([link.get_text() for link in links])
                            elif text_content.startswith('przeciw'):
                                links = child_div.find_all('a')
                                opposites.update([link.get_text() for link in links])
                    
                    synonyms = None if len(list(synonyms)) == 0 else ', '.join(list(synonyms))

                    data_list.append({
                        'english_word': ' - '.join([', '.join(english_words)] + other_forms) + ('' if synonyms == None else f' [{synonyms}]'),
                        # Dodać liste do engipa
                        'pronunciation': ' - '.join([eng_to_ipa.convert(i) for i in [word] + other_forms]) + ('' if synonyms == None else f' [{eng_to_ipa.convert(synonyms)}]'),
                        'part_of_speech': part_of_speech,
                        'polish_word': fix_string(polish_word),
                        'eng_example': eng_example,
                        'pol_example': pol_example
                    })

        self.data = pd.DataFrame(data_list)

# diki = Diki()
# diki.extract_data('draw')
# # diki.extract_data('take a toll')
# diki.data
# Out:
#                                 english_word               pronunciation  \
# 0   draw, draw out - drew - drawn [withdraw]  drɔ - dru - drɔn [wɪθˈdrɔ]
# 1                                 draw [tie]                   drɔ [taɪ]
# 2                                       draw                         drɔ
# 3                                       draw                         drɔ
# 4                                draw [drag]                  drɔ [dræg]
# 5                                       draw                         drɔ
# 6                                       draw                         drɔ
# 7                        draw - drew - drawn            drɔ - dru - drɔn
# 8                        draw - drew - drawn            drɔ - dru - drɔn
# 9                        draw - drew - drawn            drɔ - dru - drɔn
# 10                       draw - drew - drawn            drɔ - dru - drɔn
# 11                       draw - drew - drawn            drɔ - dru - drɔn
# 12                       draw - drew - drawn            drɔ - dru - drɔn
# 13                       draw - drew - drawn            drɔ - dru - drɔn
# 14                       draw - drew - drawn            drɔ - dru - drɔn
# 15                       draw - drew - drawn            drɔ - dru - drɔn
# 16                       draw - drew - drawn            drɔ - dru - drɔn
# 17                       draw - drew - drawn            drɔ - dru - drɔn
# 18                       draw - drew - drawn            drɔ - dru - drɔn
# 19                 draw - drew - drawn [tie]      drɔ - dru - drɔn [taɪ]
# 20                       draw - drew - drawn            drɔ - dru - drɔn
# 21                       draw - drew - drawn            drɔ - dru - drɔn
# 22                             draw, drawing                         drɔ
# 23                          re-entrant, draw                         drɔ
#
#    part_of_speech                                        polish_word  \
# 0       czasownik                  wyciągnąć (np. pieniądze z banku)
# 1      rzeczownik                                              remis
# 2      rzeczownik                                          losowanie
# 3      rzeczownik                                           atrakcja
# 4      rzeczownik                                             sztach
# 5      rzeczownik                                    wynik losowania
# 6      rzeczownik  coś, co przyciąga uwagę klientów i sprawia, że...
# 7       czasownik                                 rysować, szkicować
# 8       czasownik                                wywoływać (reakcję)
# 9       czasownik                                         przyciągać
# 10      czasownik                        otrzymywać, uzyskiwać (coś)
# 11      czasownik   ruszać się, poruszać się (w określonym kierunku)
# 12      czasownik                               ciągnąć (np. pojazd)
# 13      czasownik             wyciągać (np. z kieszeni, z pojemnika)
# 14      czasownik                  otrzymywać pieniądze (regularnie)
# 15      czasownik               wciągać do płuc (np. powietrze, dym)
# 16      czasownik  czerpać wodę, wziąć wodę (np. z beczki, ze stu...
# 17      czasownik                 mieć cug (np. komin, piec kaflowy)
# 18      czasownik                   ciągnąć (np. los, kartę z talii)
# 19      czasownik                                         zremisować
# 20      czasownik                                       zanurzać się
# 21      czasownik                                pobierać (np. krew)
# 22     rzeczownik                                          losowanie
# 23     rzeczownik                         liniowe zagłębienie terenu
#
#                                           eng_example  \
# 0   They accepted cash payment only, so the woman ...
# 1                          The match ended in a draw.
# 2                           I participated in a draw.
# 3                  We have a few draws up our sleeve.
# 4                                                None
# 5                                   What is the draw?
# 6                                                None
# 7                      He drew a picture on a napkin.
# 8   My tears didn't draw the reaction I was expect...
# 9   A good teacher can draw the attention of the w...
# 10               I drew the money but it wasn't easy.
# 11                        The suspect was drawing up.
# 12  I think it is exhausting for horses to draw a ...
# 13  He drew all his money out of the pocket and ga...
# 14                          He draws a small pension.
# 15                 I drew smoke and started coughing.
# 16        He drew two buckets of water from the well.
# 17            Our fireplace draws, you can add a log.
# 18         Draw one card and don't show it to anyone!
# 19  If we draw this match, we'll be promoted to th...
# 20                  He drew the cross in liquid gold.
# 21           A nurse has to draw my blood for a test.
# 22       The raffle winner will be decided by a draw.
# 23                                               None
#
#                                           pol_example
# 0   Oni akceptowali tylko płatność gotówką, więc t...
# 1                         Mecz zakończył się remisem.
# 2                         Wziąłem udział w losowaniu.
# 3                     Mamy w zanadrzu kilka atrakcji.
# 4                                                None
# 5                          Jaki jest wynik losowania?
# 6                                                None
# 7                   On narysował obrazek na serwetce.
# 8   Moje łzy nie wywołały takiej reakcji, jakiej o...
# 9   Dobry nauczyciel potrafi przyciągnąć uwagę cał...
# 10      Otrzymałem pieniądze, ale nie było to proste.
# 11      Podejrzany poruszał się w kierunku północnym.
# 12  Myślę, że ciągnięcie powozu jest dla koni męcz...
# 13  On wyciągnął z kieszeni wszystkie swoje pienią...
# 14                       On otrzymuje małą emeryturę.
# 15         Wciągnąłem dym do płuc i zacząłem kaszleć.
# 16           On zaczerpnął dwa wiadra wody ze studni.
# 17         Nasz kominek ma cug, możesz dołożyć kłodę.
# 18    Wyciągnij jedną kartę i nikomu jej nie pokazuj!
# 19  Jeśli zremisujemy ten mecz, awansujemy do fina...
# 20                On zanurzył krzyż w płynnym złocie.
# 21       Pielęgniarka musi mi pobrać krew na badanie.
# 22  Zwycięzca loterii zostanie wyłoniony przez los...
# 23                                               None

# %%
div_class = diki.soup.find_all('div', class_='dictionaryEntity')
# Out:
# ['draw', 'draw out']

# %%
english_words = ['draw', 'draw out']

# %%
# Out:
# 'draw, draw out'
